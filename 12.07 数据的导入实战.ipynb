# %% [markdown]
# # 数据的导入

# %%
import pandas as pda

# csv pda.read_csv(路径)
c = pda.read_csv("")
# excel pda.read_excel(路径)
d = pad.read_excel("")

# %%
import pandas as pda
# mysql
import pymysql
conn = pymysql.connect(host='127.0.0.1',user='root',passwd='root',db='dd')
sql = 'select * from goods'
e = pda.read_sql(sql,conn)
e
# Out:
#       id                                              title  \
# 0    289       茵曼2017冬新款连帽印花白鸭绒黑色羽绒服女长款过膝加厚保暖外套【1874121024】
# 1    290   【返场48小时 5折抢】Amii[极简主义]2017年冬装新款90绒修身长过膝加厚羽绒服女装宽松
# 2    291   【全场5折，领券满399立减110】妖精的口袋YB芝士威化饼冬装2017新款假两件连帽毛呢...
# 3    292                   初语2017春装新款假两件卫衣女中长款宽松连帽帅气拼接抓绒女装潮
# 4    293                  裂帛2017秋刺绣兜针织裤松紧腰长裤子加绒休闲裤女51151414
# 5    294             茵曼文艺灯笼袖半高领短款宽松绿色套头毛衣女长袖针织衫【1873132236】
# 6    295   【返场48小时 5折抢】Amii[极简主义]2017秋新品气质高领显瘦羊毛衫女上衣针织衫毛...
# 7    296   【全场5折，领券满399立减110】妖精的口袋W特殊行动秋装2017新款连帽抽绳宽松字母加...
# 8    297                    森宿W妈妈的暖冬装2017新款学院连帽棉衣抽绳牛角扣棉服女长款
# 9    298                     裂帛女装2017秋装新款休闲连帽刺绣长袖衫百搭拼接套头卫衣女
# 10   299                        森马棉服 冬装 女士可拆卸毛领连帽收腰中长款棉衣外套潮
# 11   300                        森马毛衣 冬装 女士圆领套头字母中长款宽松毛针织衫韩版
# 12   301     白领公社 打底裤 女士秋冬季款学生加拉绒显瘦修身保暖休闲连踩脚九分裤袜子女式纯色百搭时尚女裤
# 13   302            茵曼女装文艺范条纹长袖套头毛衣女百搭圆领打底衫修身上衣【8531320498】
# 14   303                白领公社 打底裤 女士秋冬保暖百搭踩脚一体裤子女式加绒外穿秋裤学生女裤
# ...

# %%
# html 
# html pda.read_html(路径)
f = pda.read_html("")
# 文本文档
# pda.read_tabble(路径)
g = pda.read_tabble("")
